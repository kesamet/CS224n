# %% [markdown]
# # Assignment 3

# %%
import numpy as np
from IPython.display import Image
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1 NER

# %% [markdown]
# $$ e^{(t)} \in \mathbb{R}^{D(2w+1)}, \quad W \in \mathbb{R}^{D(2w+1) \times H}, \quad U \in \mathbb{R}^{H \times C} $$

# %%
# !python q1_window.py test1
# Out:
# INFO:Testing make_windowed_data
# INFO:Passed!

# %%
# !python q1_window.py test2
# Out:
# INFO:Testing implementation of WindowModel
# INFO:Loading training data...
# INFO:Done. Read 721 sentences
# INFO:Loading dev data...
# INFO:Done. Read 721 sentences
# INFO:Built dictionary for 2653 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 0.40 seconds
# 2018-02-20 09:21:06.814656: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	5.00   	0.00   	2.00   	0.00   	817.00
# ORG    	11.00  	0.00   	0.00   	0.00   	380.00
# LOC    	4.00   	0.00   	12.00  	0.00   	561.00
# MISC   	4.00   	0.00   	1.00   	3.00   	250.00
# O      	50.00  	1.00   	12.00  	5.00   	7048.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.90 	0.07 	0.01 	0.01
# ORG  	0.00 	0.00 	0.00 	0.00
# LOC  	0.94 	0.44 	0.02 	0.04
# MISC 	0.97 	0.38 	0.01 	0.02
# O    	0.77 	0.78 	0.99 	0.87
# micro	0.91 	0.77 	0.77 	0.77
# macro	0.72 	0.33 	0.21 	0.19
# not-O	0.94 	0.18 	0.01 	0.02
#
# INFO:Entity level P/R/F1: 0.10/0.01/0.01
#
# INFO:Epoch 2 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	389.00 	0.00   	6.00   	0.00   	429.00
# ORG    	80.00  	0.00   	18.00  	0.00   	293.00
# LOC    	40.00  	0.00   	217.00 	0.00   	320.00
# MISC   	17.00  	0.00   	3.00   	0.00   	238.00
# O      	42.00  	0.00   	21.00  	0.00   	7053.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.93 	0.68 	0.47 	0.56
# ORG  	0.00 	0.00 	0.00 	0.00
# LOC  	0.96 	0.82 	0.38 	0.52
# MISC 	0.00 	0.00 	0.00 	0.00
# O    	0.85 	0.85 	0.99 	0.91
# micro	0.93 	0.84 	0.84 	0.84
# macro	0.55 	0.47 	0.37 	0.40
# not-O	0.95 	0.73 	0.30 	0.42
#
# INFO:Entity level P/R/F1: 0.42/0.20/0.27
#
# INFO:Epoch 3 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	657.00 	0.00   	8.00   	0.00   	159.00
# ORG    	186.00 	1.00   	28.00  	0.00   	176.00
# LOC    	105.00 	0.00   	275.00 	0.00   	197.00
# MISC   	68.00  	0.00   	4.00   	1.00   	185.00
# O      	131.00 	0.00   	54.00  	0.00   	6931.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.93 	0.57 	0.80 	0.67
# ORG  	0.96 	1.00 	0.00 	0.01
# LOC  	0.96 	0.75 	0.48 	0.58
# MISC 	0.97 	1.00 	0.00 	0.01
# O    	0.90 	0.91 	0.97 	0.94
# micro	0.94 	0.86 	0.86 	0.86
# macro	0.94 	0.84 	0.45 	0.44
# not-O	0.95 	0.62 	0.46 	0.52
#
# INFO:Entity level P/R/F1: 0.52/0.38/0.44
#
# INFO:Epoch 4 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	698.00 	6.00   	33.00  	1.00   	86.00
# ORG    	178.00 	37.00  	50.00  	7.00   	119.00
# LOC    	79.00  	12.00  	393.00 	5.00   	88.00
# MISC   	77.00  	14.00  	49.00  	33.00  	85.00
# O      	155.00 	13.00  	90.00  	0.00   	6858.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.93 	0.59 	0.85 	0.69
# ORG  	0.96 	0.45 	0.09 	0.16
# LOC  	0.96 	0.64 	0.68 	0.66
# MISC 	0.97 	0.72 	0.13 	0.22
# O    	0.93 	0.95 	0.96 	0.96
# micro	0.95 	0.87 	0.87 	0.87
# macro	0.95 	0.67 	0.54 	0.54
# not-O	0.95 	0.60 	0.57 	0.58
#
# INFO:Entity level P/R/F1: 0.51/0.51/0.51
#
# INFO:Epoch 5 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	684.00 	51.00  	41.00  	4.00   	44.00
# ORG    	146.00 	92.00  	49.00  	15.00  	89.00
# LOC    	54.00  	30.00  	427.00 	18.00  	48.00
# MISC   	48.00  	43.00  	47.00  	63.00  	57.00
# O      	102.00 	107.00 	119.00 	4.00   	6784.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.95 	0.66 	0.83 	0.74
# ORG  	0.94 	0.28 	0.24 	0.26
# LOC  	0.96 	0.63 	0.74 	0.68
# MISC 	0.97 	0.61 	0.24 	0.35
# O    	0.94 	0.97 	0.95 	0.96
# micro	0.95 	0.88 	0.88 	0.88
# macro	0.95 	0.63 	0.60 	0.60
# not-O	0.95 	0.59 	0.62 	0.60
#
# INFO:Entity level P/R/F1: 0.47/0.55/0.51
#
# INFO:Epoch 6 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	718.00 	16.00  	32.00  	4.00   	54.00
# ORG    	137.00 	72.00  	42.00  	25.00  	115.00
# LOC    	46.00  	17.00  	439.00 	19.00  	56.00
# MISC   	45.00  	25.00  	34.00  	86.00  	68.00
# O      	79.00  	25.00  	96.00  	2.00   	6914.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.95 	0.70 	0.87 	0.78
# ORG  	0.96 	0.46 	0.18 	0.26
# LOC  	0.96 	0.68 	0.76 	0.72
# MISC 	0.98 	0.63 	0.33 	0.44
# O    	0.95 	0.96 	0.97 	0.97
# micro	0.96 	0.90 	0.90 	0.90
# macro	0.96 	0.69 	0.62 	0.63
# not-O	0.96 	0.67 	0.64 	0.66
#
# INFO:Entity level P/R/F1: 0.55/0.58/0.57
#
# INFO:Epoch 7 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	727.00 	4.00   	22.00  	3.00   	68.00
# ORG    	148.00 	54.00  	20.00  	23.00  	146.00
# LOC    	56.00  	11.00  	415.00 	15.00  	80.00
# MISC   	50.00  	10.00  	28.00  	87.00  	83.00
# O      	73.00  	7.00   	26.00  	1.00   	7009.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.95 	0.69 	0.88 	0.77
# ORG  	0.96 	0.63 	0.14 	0.23
# LOC  	0.97 	0.81 	0.72 	0.76
# MISC 	0.98 	0.67 	0.34 	0.45
# O    	0.95 	0.95 	0.98 	0.97
# micro	0.96 	0.90 	0.90 	0.90
# macro	0.96 	0.75 	0.61 	0.64
# not-O	0.97 	0.72 	0.63 	0.67
#
# INFO:Entity level P/R/F1: 0.62/0.56/0.59
#
# INFO:Epoch 8 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	726.00 	3.00   	17.00  	3.00   	75.00
# ORG    	146.00 	58.00  	21.00  	18.00  	148.00
# LOC    	50.00  	10.00  	411.00 	13.00  	93.00
# MISC   	45.00  	11.00  	25.00  	92.00  	85.00
# O      	60.00  	8.00   	14.00  	2.00   	7032.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.71 	0.88 	0.78
# ORG  	0.96 	0.64 	0.15 	0.24
# LOC  	0.97 	0.84 	0.71 	0.77
# MISC 	0.98 	0.72 	0.36 	0.48
# O    	0.95 	0.95 	0.99 	0.97
# micro	0.96 	0.91 	0.91 	0.91
# macro	0.96 	0.77 	0.62 	0.65
# not-O	0.97 	0.74 	0.63 	0.68
#
# INFO:Entity level P/R/F1: 0.64/0.56/0.60
#
# INFO:Epoch 9 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	733.00 	6.00   	21.00  	3.00   	61.00
# ORG    	143.00 	73.00  	25.00  	14.00  	136.00
# LOC    	36.00  	16.00  	441.00 	11.00  	73.00
# MISC   	47.00  	11.00  	29.00  	94.00  	77.00
# O      	53.00  	15.00  	14.00  	2.00   	7032.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.72 	0.89 	0.80
# ORG  	0.96 	0.60 	0.19 	0.29
# LOC  	0.98 	0.83 	0.76 	0.80
# MISC 	0.98 	0.76 	0.36 	0.49
# O    	0.95 	0.95 	0.99 	0.97
# micro	0.97 	0.91 	0.91 	0.91
# macro	0.97 	0.77 	0.64 	0.67
# not-O	0.97 	0.75 	0.65 	0.70
#
# INFO:Entity level P/R/F1: 0.65/0.59/0.62
#
# INFO:Epoch 10 out of 10
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	733.00 	8.00   	25.00  	3.00   	55.00
# ORG    	130.00 	104.00 	24.00  	14.00  	119.00
# LOC    	22.00  	22.00  	469.00 	11.00  	53.00
# MISC   	41.00  	20.00  	29.00  	105.00 	63.00
# O      	51.00  	19.00  	16.00  	2.00   	7028.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.75 	0.89 	0.81
# ORG  	0.96 	0.60 	0.27 	0.37
# LOC  	0.98 	0.83 	0.81 	0.82
# MISC 	0.98 	0.78 	0.41 	0.53
# O    	0.96 	0.96 	0.99 	0.97
# micro	0.97 	0.92 	0.92 	0.92
# macro	0.97 	0.78 	0.67 	0.70
# not-O	0.97 	0.76 	0.69 	0.72
#
# INFO:Entity level P/R/F1: 0.66/0.63/0.64
#
# INFO:Model did not crash!
# INFO:Passed!

# %%
# !python q1_window.py train
# Out:
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 0.44 seconds
# 2018-02-20 09:07:54.913815: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2661.00 	134.00  	81.00   	11.00   	262.00
# ORG     	364.00  	1107.00 	226.00  	99.00   	296.00
# LOC     	119.00  	287.00  	1372.00 	91.00   	225.00
# MISC    	101.00  	252.00  	99.00   	615.00  	201.00
# O       	102.00  	143.00  	38.00   	26.00   	42450.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.80 	0.85 	0.82
# ORG  	0.96 	0.58 	0.53 	0.55
# LOC  	0.98 	0.76 	0.66 	0.70
# MISC 	0.98 	0.73 	0.49 	0.58
# O    	0.97 	0.98 	0.99 	0.98
# micro	0.98 	0.94 	0.94 	0.94
# macro	0.98 	0.77 	0.70 	0.73
# not-O	0.98 	0.73 	0.67 	0.70
#
# INFO:Entity level P/R/F1: 0.60/0.62/0.61
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 2 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2821.00 	97.00   	71.00   	18.00   	142.00
# ORG     	346.00  	1221.00 	195.00  	115.00  	215.00
# LOC     	101.00  	237.00  	1563.00 	76.00   	117.00
# MISC    	84.00   	165.00  	92.00   	776.00  	151.00
# O       	93.00   	94.00   	37.00   	37.00   	42498.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.82 	0.90 	0.86
# ORG  	0.97 	0.67 	0.58 	0.63
# LOC  	0.98 	0.80 	0.75 	0.77
# MISC 	0.99 	0.76 	0.61 	0.68
# O    	0.98 	0.99 	0.99 	0.99
# micro	0.98 	0.95 	0.95 	0.95
# macro	0.98 	0.81 	0.77 	0.78
# not-O	0.98 	0.77 	0.74 	0.76
#
# INFO:Entity level P/R/F1: 0.66/0.70/0.68
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 3 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2945.00 	63.00   	50.00   	12.00   	79.00
# ORG     	298.00  	1383.00 	157.00  	85.00   	169.00
# LOC     	95.00   	258.00  	1620.00 	47.00   	74.00
# MISC    	78.00   	144.00  	89.00   	826.00  	131.00
# O       	92.00   	103.00  	20.00   	31.00   	42513.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.84 	0.94 	0.88
# ORG  	0.98 	0.71 	0.66 	0.68
# LOC  	0.98 	0.84 	0.77 	0.80
# MISC 	0.99 	0.83 	0.65 	0.73
# O    	0.99 	0.99 	0.99 	0.99
# micro	0.98 	0.96 	0.96 	0.96
# macro	0.98 	0.84 	0.80 	0.82
# not-O	0.98 	0.81 	0.79 	0.80
#
# INFO:Entity level P/R/F1: 0.71/0.75/0.73
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 4 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2911.00 	83.00   	49.00   	17.00   	89.00
# ORG     	214.00  	1496.00 	116.00  	91.00   	175.00
# LOC     	62.00   	258.00  	1647.00 	53.00   	74.00
# MISC    	62.00   	122.00  	60.00   	903.00  	121.00
# O       	69.00   	83.00   	16.00   	41.00   	42550.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.88 	0.92 	0.90
# ORG  	0.98 	0.73 	0.72 	0.72
# LOC  	0.99 	0.87 	0.79 	0.83
# MISC 	0.99 	0.82 	0.71 	0.76
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.96 	0.96 	0.96
# macro	0.99 	0.86 	0.83 	0.84
# not-O	0.99 	0.83 	0.81 	0.82
#
# INFO:Entity level P/R/F1: 0.73/0.77/0.75
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 5 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2934.00 	43.00   	87.00   	16.00   	69.00
# ORG     	187.00  	1529.00 	161.00  	67.00   	148.00
# LOC     	65.00   	142.00  	1813.00 	26.00   	48.00
# MISC    	62.00   	81.00   	76.00   	933.00  	116.00
# O       	59.00   	70.00   	22.00   	34.00   	42574.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.89 	0.93 	0.91
# ORG  	0.98 	0.82 	0.73 	0.77
# LOC  	0.99 	0.84 	0.87 	0.85
# MISC 	0.99 	0.87 	0.74 	0.80
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.88 	0.85 	0.86
# not-O	0.99 	0.86 	0.84 	0.85
#
# INFO:Entity level P/R/F1: 0.77/0.81/0.79
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 6 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	3006.00 	23.00   	43.00   	9.00    	68.00
# ORG     	210.00  	1529.00 	137.00  	58.00   	158.00
# LOC     	74.00   	113.00  	1829.00 	18.00   	60.00
# MISC    	68.00   	53.00   	78.00   	949.00  	120.00
# O       	59.00   	56.00   	18.00   	27.00   	42599.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.88 	0.95 	0.92
# ORG  	0.98 	0.86 	0.73 	0.79
# LOC  	0.99 	0.87 	0.87 	0.87
# MISC 	0.99 	0.89 	0.75 	0.81
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.90 	0.86 	0.88
# not-O	0.99 	0.88 	0.85 	0.86
#
# INFO:Entity level P/R/F1: 0.80/0.83/0.81
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 7 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2918.00 	68.00   	79.00   	10.00   	74.00
# ORG     	129.00  	1642.00 	134.00  	50.00   	137.00
# LOC     	35.00   	128.00  	1856.00 	20.00   	55.00
# MISC    	45.00   	86.00   	61.00   	958.00  	118.00
# O       	47.00   	61.00   	21.00   	31.00   	42599.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.92 	0.93 	0.92
# ORG  	0.98 	0.83 	0.78 	0.81
# LOC  	0.99 	0.86 	0.89 	0.87
# MISC 	0.99 	0.90 	0.76 	0.82
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.90 	0.87 	0.88
# not-O	0.99 	0.88 	0.86 	0.87
#
# INFO:Entity level P/R/F1: 0.80/0.83/0.81
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 8 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2988.00 	42.00   	38.00   	17.00   	64.00
# ORG     	158.00  	1619.00 	108.00  	71.00   	136.00
# LOC     	52.00   	144.00  	1813.00 	35.00   	50.00
# MISC    	43.00   	58.00   	40.00   	1019.00 	108.00
# O       	50.00   	50.00   	14.00   	39.00   	42606.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.91 	0.95 	0.93
# ORG  	0.99 	0.85 	0.77 	0.81
# LOC  	0.99 	0.90 	0.87 	0.88
# MISC 	0.99 	0.86 	0.80 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.90 	0.88 	0.89
# not-O	0.99 	0.89 	0.86 	0.88
#
# INFO:Entity level P/R/F1: 0.81/0.84/0.82
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
#
# INFO:Epoch 9 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 1s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2964.00 	42.00   	70.00   	12.00   	61.00
# ORG     	144.00  	1653.00 	103.00  	71.00   	121.00
# LOC     	41.00   	113.00  	1859.00 	32.00   	49.00
# MISC    	37.00   	51.00   	50.00   	1023.00 	107.00
# O       	43.00   	52.00   	20.00   	37.00   	42607.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.92 	0.94 	0.93
# ORG  	0.99 	0.86 	0.79 	0.83
# LOC  	0.99 	0.88 	0.89 	0.89
# MISC 	0.99 	0.87 	0.81 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.88 	0.89
# not-O	0.99 	0.89 	0.87 	0.88
#
# INFO:Entity level P/R/F1: 0.81/0.85/0.83
# INFO:New best score! Saving model in results/window/20180220_090751/model.weights
# INFO:Epoch 10 out of 10
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2926.00 	51.00   	82.00   	17.00   	73.00
# ORG     	124.00  	1646.00 	118.00  	77.00   	127.00
# LOC     	28.00   	118.00  	1858.00 	33.00   	57.00
# MISC    	29.00   	45.00   	49.00   	1032.00 	113.00
# O       	37.00   	52.00   	19.00   	32.00   	42619.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.93 	0.93
# ORG  	0.99 	0.86 	0.79 	0.82
# LOC  	0.99 	0.87 	0.89 	0.88
# MISC 	0.99 	0.87 	0.81 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.90 	0.88 	0.89
# not-O	0.99 	0.89 	0.87 	0.88
#
# INFO:Entity level P/R/F1: 0.81/0.84/0.83
#
# 26/26 [==============================] - 0s

# %% [markdown]
# ## 2 Recurrent neural nets for NER

# %%
# !python q2_rnn_cell.py test
# Out:
# INFO:Testing rnn_cell
# 2018-02-20 09:27:11.663089: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# y_ = [[0.8320184  0.880797  ]
#  [0.7310586  0.62245935]]
# ht_ = [[0.8320184  0.880797  ]
#  [0.7310586  0.62245935]]
# INFO:Passed!

# %%
# !python q2_rnn.py test1
# Out:
# INFO:Testing pad_sequences
# INFO:Passed!

# %%
# !python q2_rnn.py test2
# Out:
# INFO:Testing implementation of RNNModel
# INFO:Loading training data...
# INFO:Done. Read 721 sentences
# INFO:Loading dev data...
# INFO:Done. Read 721 sentences
# INFO:Built dictionary for 2653 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 2.65 seconds
# 2018-02-20 09:27:19.022971: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	598.00 	0.00   	40.00  	0.00   	186.00
# ORG    	137.00 	0.00   	61.00  	0.00   	193.00
# LOC    	47.00  	0.00   	330.00 	0.00   	200.00
# MISC   	50.00  	0.00   	22.00  	0.00   	186.00
# O      	70.00  	0.00   	139.00 	0.00   	6907.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.94 	0.66 	0.73 	0.69
# ORG  	0.00 	0.00 	0.00 	0.00
# LOC  	0.94 	0.56 	0.57 	0.56
# MISC 	0.00 	0.00 	0.00 	0.00
# O    	0.89 	0.90 	0.97 	0.93
# micro	0.94 	0.85 	0.85 	0.85
# macro	0.56 	0.42 	0.45 	0.44
# not-O	0.95 	0.62 	0.45 	0.52
#
# INFO:Entity level P/R/F1: 0.50/0.39/0.44
#
# INFO:Epoch 2 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 3s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	722.00 	0.00   	23.00  	0.00   	79.00
# ORG    	226.00 	0.00   	27.00  	1.00   	137.00
# LOC    	95.00  	0.00   	380.00 	4.00   	98.00
# MISC   	86.00  	0.00   	52.00  	39.00  	81.00
# O      	99.00  	0.00   	57.00  	0.00   	6960.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.93 	0.59 	0.88 	0.70
# ORG  	0.00 	0.00 	0.00 	0.00
# LOC  	0.96 	0.71 	0.66 	0.68
# MISC 	0.98 	0.89 	0.15 	0.26
# O    	0.94 	0.95 	0.98 	0.96
# micro	0.95 	0.88 	0.88 	0.88
# macro	0.76 	0.63 	0.53 	0.52
# not-O	0.96 	0.63 	0.56 	0.59
#
# INFO:Entity level P/R/F1: 0.58/0.51/0.55
#
# INFO:Epoch 3 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 3s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	751.00 	2.00   	18.00  	2.00   	51.00
# ORG    	204.00 	24.00  	20.00  	14.00  	129.00
# LOC    	80.00  	6.00   	399.00 	14.00  	78.00
# MISC   	67.00  	5.00   	13.00  	105.00 	68.00
# O      	88.00  	2.00   	21.00  	2.00   	7003.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.94 	0.63 	0.91 	0.75
# ORG  	0.96 	0.62 	0.06 	0.11
# LOC  	0.97 	0.85 	0.69 	0.76
# MISC 	0.98 	0.77 	0.41 	0.53
# O    	0.95 	0.96 	0.98 	0.97
# micro	0.96 	0.90 	0.90 	0.90
# macro	0.96 	0.76 	0.61 	0.62
# not-O	0.96 	0.70 	0.62 	0.66
#
# INFO:Entity level P/R/F1: 0.64/0.58/0.61
#
# INFO:Epoch 4 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	727.00 	1.00   	25.00  	4.00   	67.00
# ORG    	163.00 	23.00  	33.00  	23.00  	149.00
# LOC    	34.00  	1.00   	463.00 	15.00  	64.00
# MISC   	44.00  	5.00   	18.00  	122.00 	69.00
# O      	58.00  	4.00   	20.00  	2.00   	7032.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.71 	0.88 	0.79
# ORG  	0.96 	0.68 	0.06 	0.11
# LOC  	0.98 	0.83 	0.80 	0.82
# MISC 	0.98 	0.73 	0.47 	0.58
# O    	0.95 	0.95 	0.99 	0.97
# micro	0.97 	0.91 	0.91 	0.91
# macro	0.97 	0.78 	0.64 	0.65
# not-O	0.97 	0.75 	0.65 	0.70
#
# INFO:Entity level P/R/F1: 0.66/0.61/0.63
#
# INFO:Epoch 5 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	740.00 	19.00  	22.00  	2.00   	41.00
# ORG    	117.00 	134.00 	23.00  	9.00   	108.00
# LOC    	26.00  	31.00  	472.00 	8.00   	40.00
# MISC   	35.00  	37.00  	26.00  	107.00 	53.00
# O      	41.00  	39.00  	16.00  	0.00   	7020.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.97 	0.77 	0.90 	0.83
# ORG  	0.96 	0.52 	0.34 	0.41
# LOC  	0.98 	0.84 	0.82 	0.83
# MISC 	0.98 	0.85 	0.41 	0.56
# O    	0.96 	0.97 	0.99 	0.98
# micro	0.97 	0.92 	0.92 	0.92
# macro	0.97 	0.79 	0.69 	0.72
# not-O	0.97 	0.76 	0.71 	0.73
#
# INFO:Entity level P/R/F1: 0.65/0.65/0.65
#
# INFO:Epoch 6 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	772.00 	1.00   	12.00  	5.00   	34.00
# ORG    	166.00 	40.00  	28.00  	32.00  	125.00
# LOC    	39.00  	2.00   	476.00 	17.00  	43.00
# MISC   	39.00  	3.00   	14.00  	150.00 	52.00
# O      	55.00  	8.00   	6.00   	3.00   	7044.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.72 	0.94 	0.81
# ORG  	0.96 	0.74 	0.10 	0.18
# LOC  	0.98 	0.89 	0.82 	0.86
# MISC 	0.98 	0.72 	0.58 	0.65
# O    	0.96 	0.97 	0.99 	0.98
# micro	0.97 	0.93 	0.93 	0.93
# macro	0.97 	0.81 	0.69 	0.69
# not-O	0.97 	0.77 	0.70 	0.73
#
# INFO:Entity level P/R/F1: 0.69/0.67/0.68
#
# INFO:Epoch 7 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	776.00 	7.00   	10.00  	3.00   	28.00
# ORG    	125.00 	128.00 	21.00  	21.00  	96.00
# LOC    	23.00  	19.00  	487.00 	12.00  	36.00
# MISC   	29.00  	18.00  	9.00   	156.00 	46.00
# O      	39.00  	25.00  	7.00   	2.00   	7043.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.97 	0.78 	0.94 	0.85
# ORG  	0.96 	0.65 	0.33 	0.44
# LOC  	0.99 	0.91 	0.84 	0.88
# MISC 	0.98 	0.80 	0.60 	0.69
# O    	0.97 	0.97 	0.99 	0.98
# micro	0.97 	0.94 	0.94 	0.94
# macro	0.97 	0.82 	0.74 	0.77
# not-O	0.98 	0.81 	0.75 	0.78
#
# INFO:Entity level P/R/F1: 0.70/0.71/0.70
#
# INFO:Epoch 8 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	777.00 	10.00  	10.00  	3.00   	24.00
# ORG    	86.00  	176.00 	28.00  	13.00  	88.00
# LOC    	9.00   	23.00  	509.00 	4.00   	32.00
# MISC   	25.00  	23.00  	19.00  	149.00 	42.00
# O      	28.00  	35.00  	6.00   	1.00   	7046.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.84 	0.94 	0.89
# ORG  	0.97 	0.66 	0.45 	0.53
# LOC  	0.99 	0.89 	0.88 	0.89
# MISC 	0.99 	0.88 	0.58 	0.70
# O    	0.97 	0.97 	0.99 	0.98
# micro	0.98 	0.94 	0.94 	0.94
# macro	0.98 	0.85 	0.77 	0.80
# not-O	0.98 	0.83 	0.79 	0.81
#
# INFO:Entity level P/R/F1: 0.72/0.74/0.73
#
# INFO:Epoch 9 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	791.00 	6.00   	4.00   	5.00   	18.00
# ORG    	90.00  	164.00 	15.00  	47.00  	75.00
# LOC    	17.00  	15.00  	487.00 	30.00  	28.00
# MISC   	25.00  	10.00  	3.00   	193.00 	27.00
# O      	31.00  	26.00  	3.00   	4.00   	7052.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.83 	0.96 	0.89
# ORG  	0.97 	0.74 	0.42 	0.54
# LOC  	0.99 	0.95 	0.84 	0.89
# MISC 	0.98 	0.69 	0.75 	0.72
# O    	0.98 	0.98 	0.99 	0.99
# micro	0.98 	0.95 	0.95 	0.95
# macro	0.98 	0.84 	0.79 	0.80
# not-O	0.98 	0.83 	0.80 	0.81
#
# INFO:Entity level P/R/F1: 0.72/0.75/0.74
#
# INFO:Epoch 10 out of 10
# INFO:Evaluating on development data
# 23/23 [==============================] - 4s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	795.00 	7.00   	4.00   	3.00   	15.00
# ORG    	54.00  	239.00 	13.00  	12.00  	73.00
# LOC    	8.00   	39.00  	493.00 	8.00   	29.00
# MISC   	20.00  	29.00  	6.00   	177.00 	26.00
# O      	17.00  	29.00  	1.00   	3.00   	7066.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.89 	0.96 	0.93
# ORG  	0.97 	0.70 	0.61 	0.65
# LOC  	0.99 	0.95 	0.85 	0.90
# MISC 	0.99 	0.87 	0.69 	0.77
# O    	0.98 	0.98 	0.99 	0.99
# micro	0.98 	0.96 	0.96 	0.96
# macro	0.98 	0.88 	0.82 	0.85
# not-O	0.98 	0.87 	0.83 	0.85
#
# INFO:Entity level P/R/F1: 0.77/0.78/0.78
#
# INFO:Model did not crash!
# INFO:Passed!

# %%
# !python q2_rnn.py train #2h on CPU
# Out:
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 6.04 seconds
# 2018-02-20 09:28:57.379564: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 42s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2881.00 	44.00   	46.00   	13.00   	165.00
# ORG     	341.00  	1114.00 	204.00  	179.00  	254.00
# LOC     	127.00  	177.00  	1564.00 	112.00  	114.00
# MISC    	76.00   	144.00  	67.00   	825.00  	156.00
# O       	82.00   	63.00   	21.00   	41.00   	42552.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.82 	0.91 	0.87
# ORG  	0.97 	0.72 	0.53 	0.61
# LOC  	0.98 	0.82 	0.75 	0.78
# MISC 	0.98 	0.71 	0.65 	0.68
# O    	0.98 	0.98 	1.00 	0.99
# micro	0.98 	0.95 	0.95 	0.95
# macro	0.98 	0.81 	0.77 	0.79
# not-O	0.98 	0.79 	0.74 	0.76
#
# INFO:Entity level P/R/F1: 0.68/0.70/0.69
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 2 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 42s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2876.00 	55.00   	72.00   	16.00   	130.00
# ORG     	182.00  	1470.00 	146.00  	77.00   	217.00
# LOC     	57.00   	155.00  	1766.00 	29.00   	87.00
# MISC    	44.00   	118.00  	78.00   	883.00  	145.00
# O       	45.00   	57.00   	16.00   	27.00   	42614.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.90 	0.91 	0.91
# ORG  	0.98 	0.79 	0.70 	0.74
# LOC  	0.99 	0.85 	0.84 	0.85
# MISC 	0.99 	0.86 	0.70 	0.77
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.88 	0.83 	0.85
# not-O	0.99 	0.86 	0.81 	0.83
#
# INFO:Entity level P/R/F1: 0.77/0.78/0.77
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 3 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 43s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2999.00 	23.00   	39.00   	7.00    	81.00
# ORG     	193.00  	1564.00 	93.00   	68.00   	174.00
# LOC     	74.00   	156.00  	1782.00 	21.00   	61.00
# MISC    	62.00   	87.00   	58.00   	925.00  	136.00
# O       	50.00   	48.00   	13.00   	26.00   	42622.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.89 	0.95 	0.92
# ORG  	0.98 	0.83 	0.75 	0.79
# LOC  	0.99 	0.90 	0.85 	0.87
# MISC 	0.99 	0.88 	0.73 	0.80
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.90 	0.86 	0.87
# not-O	0.99 	0.88 	0.85 	0.86
#
# INFO:Entity level P/R/F1: 0.80/0.82/0.81
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 4 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 64s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2987.00 	26.00   	50.00   	17.00   	69.00
# ORG     	149.00  	1591.00 	111.00  	74.00   	167.00
# LOC     	41.00   	118.00  	1869.00 	16.00   	50.00
# MISC    	39.00   	71.00   	56.00   	985.00  	117.00
# O       	41.00   	42.00   	18.00   	32.00   	42626.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.92 	0.95 	0.93
# ORG  	0.99 	0.86 	0.76 	0.81
# LOC  	0.99 	0.89 	0.89 	0.89
# MISC 	0.99 	0.88 	0.78 	0.82
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.91 	0.88 	0.89
# not-O	0.99 	0.89 	0.86 	0.88
#
# INFO:Entity level P/R/F1: 0.82/0.84/0.83
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 5 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 68s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2954.00 	47.00   	69.00   	15.00   	64.00
# ORG     	117.00  	1698.00 	90.00   	52.00   	135.00
# LOC     	30.00   	137.00  	1871.00 	13.00   	43.00
# MISC    	33.00   	93.00   	48.00   	983.00  	111.00
# O       	37.00   	50.00   	21.00   	25.00   	42626.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.94 	0.93
# ORG  	0.99 	0.84 	0.81 	0.82
# LOC  	0.99 	0.89 	0.89 	0.89
# MISC 	0.99 	0.90 	0.78 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.88 	0.90
# not-O	0.99 	0.90 	0.87 	0.88
#
# INFO:Entity level P/R/F1: 0.82/0.85/0.83
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 6 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 69s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2936.00 	40.00   	101.00  	14.00   	58.00
# ORG     	114.00  	1665.00 	147.00  	58.00   	108.00
# LOC     	26.00   	66.00   	1962.00 	9.00    	31.00
# MISC    	30.00   	68.00   	83.00   	984.00  	103.00
# O       	39.00   	59.00   	33.00   	32.00   	42596.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.93 	0.93
# ORG  	0.99 	0.88 	0.80 	0.83
# LOC  	0.99 	0.84 	0.94 	0.89
# MISC 	0.99 	0.90 	0.78 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.89 	0.88 	0.88
#
# INFO:Entity level P/R/F1: 0.83/0.85/0.84
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 7 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 66s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2961.00 	38.00   	52.00   	28.00   	70.00
# ORG     	104.00  	1655.00 	73.00   	119.00  	141.00
# LOC     	36.00   	102.00  	1846.00 	70.00   	40.00
# MISC    	26.00   	37.00   	27.00   	1064.00 	114.00
# O       	34.00   	34.00   	15.00   	41.00   	42635.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.94 	0.94 	0.94
# ORG  	0.99 	0.89 	0.79 	0.84
# LOC  	0.99 	0.92 	0.88 	0.90
# MISC 	0.99 	0.80 	0.84 	0.82
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.90 	0.87 	0.89
#
# INFO:Entity level P/R/F1: 0.83/0.85/0.84
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 8 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 69s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2983.00 	38.00   	40.00   	26.00   	62.00
# ORG     	110.00  	1679.00 	69.00   	114.00  	120.00
# LOC     	35.00   	105.00  	1877.00 	45.00   	32.00
# MISC    	28.00   	41.00   	32.00   	1059.00 	108.00
# O       	39.00   	51.00   	13.00   	33.00   	42623.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.95 	0.94
# ORG  	0.99 	0.88 	0.80 	0.84
# LOC  	0.99 	0.92 	0.90 	0.91
# MISC 	0.99 	0.83 	0.84 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.90 	0.90
# not-O	0.99 	0.90 	0.88 	0.89
#
# INFO:Entity level P/R/F1: 0.84/0.86/0.85
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
#
# INFO:Epoch 9 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 69s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2959.00 	67.00   	35.00   	20.00   	68.00
# ORG     	86.00   	1787.00 	39.00   	69.00   	111.00
# LOC     	26.00   	144.00  	1861.00 	26.00   	37.00
# MISC    	26.00   	73.00   	32.00   	1027.00 	110.00
# O       	32.00   	69.00   	7.00    	28.00   	42623.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.95 	0.94 	0.94
# ORG  	0.99 	0.84 	0.85 	0.84
# LOC  	0.99 	0.94 	0.89 	0.91
# MISC 	0.99 	0.88 	0.81 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.92 	0.90 	0.91
# not-O	0.99 	0.91 	0.89 	0.90
#
# INFO:Entity level P/R/F1: 0.85/0.86/0.85
# INFO:New best score! Saving model in results/rnn/20180220_092848/model.weights
# INFO:Epoch 10 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 74s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2835.00 	75.00   	145.00  	23.00   	71.00
# ORG     	66.00   	1746.00 	104.00  	85.00   	91.00
# LOC     	12.00   	72.00   	1956.00 	19.00   	35.00
# MISC    	15.00   	53.00   	67.00   	1045.00 	88.00
# O       	26.00   	57.00   	29.00   	41.00   	42606.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.96 	0.90 	0.93
# ORG  	0.99 	0.87 	0.83 	0.85
# LOC  	0.99 	0.85 	0.93 	0.89
# MISC 	0.99 	0.86 	0.82 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.90 	0.90
# not-O	0.99 	0.90 	0.88 	0.89
#
# INFO:Entity level P/R/F1: 0.83/0.86/0.84
#
# 102/102 [==============================] - 74s

# %% [markdown]
# ## 3 GRU

# %% [markdown]
# ### Modelling latching behaviour
#
# #### RNN
# - Case 1: $x^{(t)}=0, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=0$
# $$ \sigma(b_h) = 0 \Rightarrow b_h \le 0 $$
#
# - Case 2: $x^{(t)}=0, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(U_h+b_h) = 1 \Rightarrow U_h+b_h > 0 $$
#
# - Case 3: $x^{(t)}=1, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(W_h+b_h) = 1 \Rightarrow W_h+b_h > 0 $$
#
# - Case 4: $x^{(t)}=1, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(W_h+U_h+b_h) = 1 \Rightarrow W_h+U_h+b_h > 0 $$
#
# Thus,
# $$ U_h+b_h > 0, \quad W_h+b_h > 0, \quad b_h \le 0 $$
#
# #### GRU
# Since $W_r=U_r=b_r=b_z=b_h=0$,
# $$ z^{(t)} = \sigma(x^{(t)}W_z + h^{(t-1)}U_z) $$
# $$ r^{(t)} = 0 $$
# $$ \tilde{h}^{(t)} = \tanh(x^{(t)}W_h) $$
# $$ h^{(t)} = z^{(t)}h^{(t-1)} + (1-z^{(t)})\tanh(x^{(t)}W_h) $$
#
# - Case 1: $x^{(t)}=0, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=0$
# $$ U_z, U_h, W_z, W_h \in \mathbb{R} $$
#
# - Case 2: $x^{(t)}=0, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(U_z) = 1 \Rightarrow U_z > 0 $$
#
# - Case 3: $x^{(t)}=1, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=1$
# $$ (1-\sigma(W_z))\tanh(x^{(t)}W_h) = 1 \Rightarrow W_h > 0, W_z \le 0 $$
#
# - Case 4: $x^{(t)}=1, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=1$
# $$  U_h \in \mathbb{R} $$
#
# Thus,
# $$ U_z > 0, \quad U_h \in \mathbb{R}, \quad W_h > 0, \quad W_z \le 0 $$

# %% [markdown]
# ### Modelling toggling behaviour
#
# #### RNN
# - Case 1: $x^{(t)}=0, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=0$
# $$ \sigma(b_h) = 0 \Rightarrow b_h \le 0 $$
#
# - Case 2: $x^{(t)}=0, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(U_h+b_h) = 1 \Rightarrow U_h+b_h > 0 $$
#
# - Case 3: $x^{(t)}=1, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(W_h+b_h) = 1 \Rightarrow W_h+b_h > 0 $$
#
# - Case 4: $x^{(t)}=1, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=0$
# $$ \sigma(W_h+U_h+b_h) = 0 \Rightarrow W_h+U_h+b_h \le 0 $$
#
# We have a contradiction.
#
# #### GRU
# Since $W_r=U_r=b_z=b_h=0$,
# $$ z^{(t)} = \sigma(x^{(t)}W_z + h^{(t-1)}U_z) $$
# $$ r^{(t)} = \sigma(b_r) $$
# $$ \tilde{h}^{(t)} = \tanh(x^{(t)}W_h + r^{(t)}h^{(t-1)}U_h) $$
# $$ h^{(t)} = z^{(t)}h^{(t-1)} + (1-z^{(t)})\tanh(x^{(t)}W_h + r^{(t)}h^{(t-1)}U_h) $$
#
# - Case 1: $x^{(t)}=0, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=0$
# $$ U_z, U_h, W_z, W_h \in \mathbb{R} $$
#
# - Case 2: $x^{(t)}=0, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(U_z) + (1-\sigma(U_z))\tanh(\sigma(b_r)U_h) = 1 $$
#
# - Case 3: $x^{(t)}=1, h^{(t-1)}=0 \Rightarrow h^{(t-1)}=1$
# $$ \sigma(W_z) + (1-\sigma(W_z))\tanh(W_h) = 1 $$
#
# - Case 4: $x^{(t)}=1, h^{(t-1)}=1 \Rightarrow h^{(t-1)}=0$
# $$ \sigma(W_z+U_z) + (1-\sigma(W_z+U_z))\tanh(W_h + \sigma(b_r)U_h) = 0 $$

# %%
# !python q3_gru_cell.py test
# Out:
# INFO:Testing gru_cell
# 2018-02-20 10:15:30.920684: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# y_ = [[ 0.32035077  0.55478156]
#  [-0.00592546  0.0195577 ]]
# ht_ = [[ 0.32035077  0.55478156]
#  [-0.00592546  0.0195577 ]]
# INFO:Passed!

# %%
# !python q3_gru.py predict -c rnn -g
# Out:
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# INFO:Building model...
# INFO:took 0.36 seconds
# 2018-02-20 10:15:33.827702: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5980
# INFO:Epoch 2 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5083
# INFO:Epoch 3 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5035
# INFO:Epoch 4 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5016
# INFO:Epoch 5 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5007
# INFO:Epoch 6 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5000
# INFO:Epoch 7 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4996
# INFO:Epoch 8 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4993
# INFO:Epoch 9 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4991
# INFO:Epoch 10 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4989
# INFO:Epoch 11 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4988
# INFO:Epoch 12 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4987
# INFO:Epoch 13 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4986
# INFO:Epoch 14 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4985
# INFO:Epoch 15 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4984
# INFO:Epoch 16 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4984
# INFO:Epoch 17 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4983
# INFO:Epoch 18 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4983
# INFO:Epoch 19 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4982
# INFO:Epoch 20 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4982
# INFO:Epoch 21 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4982
# INFO:Epoch 22 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4981
# INFO:Epoch 23 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4981
# INFO:Epoch 24 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4981
# INFO:Epoch 25 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 26 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 27 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 28 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 29 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 30 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 31 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 32 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 33 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 34 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 35 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 36 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 37 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 38 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 39 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4978
# INFO:Epoch 40 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4978

# %%
Image('q3-clip-rnn.png')

# %%
# !python q3_gru.py predict -c rnn
# Out:
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# INFO:Building model...
# INFO:took 0.35 seconds
# 2018-02-20 10:17:08.118204: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5980
# INFO:Epoch 2 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5083
# INFO:Epoch 3 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5035
# INFO:Epoch 4 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5016
# INFO:Epoch 5 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5007
# INFO:Epoch 6 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5000
# INFO:Epoch 7 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4996
# INFO:Epoch 8 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4993
# INFO:Epoch 9 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4991
# INFO:Epoch 10 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4989
# INFO:Epoch 11 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4988
# INFO:Epoch 12 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4987
# INFO:Epoch 13 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4986
# INFO:Epoch 14 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4985
# INFO:Epoch 15 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4984
# INFO:Epoch 16 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4984
# INFO:Epoch 17 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4983
# INFO:Epoch 18 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4983
# INFO:Epoch 19 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4982
# INFO:Epoch 20 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4982
# INFO:Epoch 21 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4982
# INFO:Epoch 22 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4981
# INFO:Epoch 23 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4981
# INFO:Epoch 24 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4981
# INFO:Epoch 25 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 26 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 27 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 28 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 29 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 30 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4980
# INFO:Epoch 31 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 32 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 33 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 34 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 35 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 36 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 37 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 38 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4979
# INFO:Epoch 39 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4978
# INFO:Epoch 40 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4978

# %%
Image('q3-noclip-rnn.png')

# %%
# !python q3_gru.py predict -c gru -g
# Out:
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# INFO:Building model...
# INFO:took 0.64 seconds
# 2018-02-20 10:17:22.937874: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5305
# INFO:Epoch 2 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5436
# INFO:Epoch 3 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5141
# INFO:Epoch 4 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5159
# INFO:Epoch 5 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5198
# INFO:Epoch 6 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5163
# INFO:Epoch 7 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5086
# INFO:Epoch 8 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5096
# INFO:Epoch 9 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5084
# INFO:Epoch 10 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5073
# INFO:Epoch 11 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5048
# INFO:Epoch 12 out of 40
# 100/100 [==============================] - 0s - train loss: 4.1749
# INFO:Epoch 13 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6573
# INFO:Epoch 14 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6402
# INFO:Epoch 15 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6332
# INFO:Epoch 16 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6293
# INFO:Epoch 17 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6269
# INFO:Epoch 18 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6252
# INFO:Epoch 19 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6239
# INFO:Epoch 20 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6230
# INFO:Epoch 21 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6222
# INFO:Epoch 22 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6216
# INFO:Epoch 23 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6211
# INFO:Epoch 24 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6207
# INFO:Epoch 25 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6203
# INFO:Epoch 26 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6200
# INFO:Epoch 27 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6197
# INFO:Epoch 28 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6195
# INFO:Epoch 29 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6193
# INFO:Epoch 30 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6191
# INFO:Epoch 31 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6189
# INFO:Epoch 32 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6188
# INFO:Epoch 33 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6186
# INFO:Epoch 34 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6185
# INFO:Epoch 35 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6184
# INFO:Epoch 36 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6183
# INFO:Epoch 37 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6182
# INFO:Epoch 38 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6181
# INFO:Epoch 39 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6180
# INFO:Epoch 40 out of 40
# 100/100 [==============================] - 0s - train loss: 3.6179

# %%
Image('q3-clip-gru.png')

# %%
# !python q3_gru.py predict -c gru
# Out:
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# INFO:Building model...
# INFO:took 0.57 seconds
# 2018-02-20 10:17:52.106608: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5305
# INFO:Epoch 2 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5436
# INFO:Epoch 3 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5141
# INFO:Epoch 4 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5159
# INFO:Epoch 5 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5198
# INFO:Epoch 6 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5163
# INFO:Epoch 7 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5086
# INFO:Epoch 8 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5096
# INFO:Epoch 9 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5084
# INFO:Epoch 10 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5073
# INFO:Epoch 11 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5048
# INFO:Epoch 12 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5109
# INFO:Epoch 13 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5110
# INFO:Epoch 14 out of 40
# 100/100 [==============================] - 0s - train loss: 12.9641
# INFO:Epoch 15 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5466
# INFO:Epoch 16 out of 40
# 100/100 [==============================] - 0s - train loss: 12.5013
# INFO:Epoch 17 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4959
# INFO:Epoch 18 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4944
# INFO:Epoch 19 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4937
# INFO:Epoch 20 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4933
# INFO:Epoch 21 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4932
# INFO:Epoch 22 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4930
# INFO:Epoch 23 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4929
# INFO:Epoch 24 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4928
# INFO:Epoch 25 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4927
# INFO:Epoch 26 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4927
# INFO:Epoch 27 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4926
# INFO:Epoch 28 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4926
# INFO:Epoch 29 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4926
# INFO:Epoch 30 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4925
# INFO:Epoch 31 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4925
# INFO:Epoch 32 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4925
# INFO:Epoch 33 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4924
# INFO:Epoch 34 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4924
# INFO:Epoch 35 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4924
# INFO:Epoch 36 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4924
# INFO:Epoch 37 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4923
# INFO:Epoch 38 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4924
# INFO:Epoch 39 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4924
# INFO:Epoch 40 out of 40
# 100/100 [==============================] - 0s - train loss: 12.4923

# %%
Image('q3-noclip-gru.png')

# %%
# !python q2_rnn.py train -c gru #4h on CPU
# Out:
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/kokmeng/anaconda3/envs/py27/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 13.87 seconds
# 2018-02-20 10:18:38.410743: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 98s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2602.00 	358.00  	80.00   	19.00   	90.00
# ORG     	114.00  	1683.00 	135.00  	42.00   	118.00
# LOC     	42.00   	242.00  	1735.00 	20.00   	55.00
# MISC    	28.00   	268.00  	120.00  	743.00  	109.00
# O       	52.00   	151.00  	58.00   	50.00   	42448.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.92 	0.83 	0.87
# ORG  	0.97 	0.62 	0.80 	0.70
# LOC  	0.99 	0.82 	0.83 	0.82
# MISC 	0.99 	0.85 	0.59 	0.69
# O    	0.99 	0.99 	0.99 	0.99
# micro	0.98 	0.96 	0.96 	0.96
# macro	0.98 	0.84 	0.81 	0.82
# not-O	0.98 	0.79 	0.79 	0.79
#
# INFO:Entity level P/R/F1: 0.70/0.75/0.73
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 2 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 92s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2779.00 	176.00  	88.00   	27.00   	79.00
# ORG     	120.00  	1649.00 	92.00   	102.00  	129.00
# LOC     	23.00   	156.00  	1807.00 	47.00   	61.00
# MISC    	30.00   	102.00  	59.00   	966.00  	111.00
# O       	36.00   	94.00   	27.00   	61.00   	42541.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.88 	0.91
# ORG  	0.98 	0.76 	0.79 	0.77
# LOC  	0.99 	0.87 	0.86 	0.87
# MISC 	0.99 	0.80 	0.76 	0.78
# O    	0.99 	0.99 	0.99 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.87 	0.86 	0.86
# not-O	0.99 	0.85 	0.84 	0.84
#
# INFO:Entity level P/R/F1: 0.78/0.80/0.79
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 3 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 96s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2817.00 	150.00  	90.00   	19.00   	73.00
# ORG     	113.00  	1756.00 	79.00   	54.00   	90.00
# LOC     	20.00   	209.00  	1802.00 	20.00   	43.00
# MISC    	27.00   	130.00  	50.00   	961.00  	100.00
# O       	42.00   	105.00  	17.00   	44.00   	42551.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.89 	0.91
# ORG  	0.98 	0.75 	0.84 	0.79
# LOC  	0.99 	0.88 	0.86 	0.87
# MISC 	0.99 	0.88 	0.76 	0.81
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.89 	0.87 	0.88
# not-O	0.99 	0.86 	0.85 	0.86
#
# INFO:Entity level P/R/F1: 0.80/0.82/0.81
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 4 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 95s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2993.00 	32.00   	31.00   	9.00    	84.00
# ORG     	164.00  	1582.00 	91.00   	107.00  	148.00
# LOC     	67.00   	75.00   	1884.00 	24.00   	44.00
# MISC    	55.00   	32.00   	57.00   	1003.00 	121.00
# O       	39.00   	38.00   	12.00   	40.00   	42630.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.90 	0.95 	0.93
# ORG  	0.99 	0.90 	0.76 	0.82
# LOC  	0.99 	0.91 	0.90 	0.90
# MISC 	0.99 	0.85 	0.79 	0.82
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.88 	0.89
# not-O	0.99 	0.90 	0.87 	0.88
#
# INFO:Entity level P/R/F1: 0.83/0.85/0.84
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 5 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 89s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2917.00 	48.00   	61.00   	28.00   	95.00
# ORG     	129.00  	1657.00 	87.00   	85.00   	134.00
# LOC     	37.00   	93.00   	1896.00 	26.00   	42.00
# MISC    	35.00   	46.00   	41.00   	1038.00 	108.00
# O       	24.00   	53.00   	16.00   	40.00   	42626.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.93 	0.93 	0.93
# ORG  	0.99 	0.87 	0.79 	0.83
# LOC  	0.99 	0.90 	0.91 	0.90
# MISC 	0.99 	0.85 	0.82 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.90 	0.87 	0.89
#
# INFO:Entity level P/R/F1: 0.84/0.85/0.84
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 6 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 95s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2870.00 	75.00   	95.00   	22.00   	87.00
# ORG     	94.00   	1730.00 	98.00   	86.00   	84.00
# LOC     	27.00   	84.00   	1940.00 	13.00   	30.00
# MISC    	22.00   	55.00   	59.00   	1031.00 	101.00
# O       	21.00   	86.00   	30.00   	39.00   	42583.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.95 	0.91 	0.93
# ORG  	0.99 	0.85 	0.83 	0.84
# LOC  	0.99 	0.87 	0.93 	0.90
# MISC 	0.99 	0.87 	0.81 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.89 	0.88 	0.89
#
# INFO:Entity level P/R/F1: 0.84/0.85/0.84
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 7 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 95s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2881.00 	49.00   	35.00   	6.00    	178.00
# ORG     	98.00   	1687.00 	95.00   	43.00   	169.00
# LOC     	31.00   	84.00   	1903.00 	4.00    	72.00
# MISC    	33.00   	66.00   	54.00   	976.00  	139.00
# O       	21.00   	50.00   	13.00   	24.00   	42651.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.94 	0.91 	0.93
# ORG  	0.99 	0.87 	0.81 	0.84
# LOC  	0.99 	0.91 	0.91 	0.91
# MISC 	0.99 	0.93 	0.77 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.93 	0.88 	0.90
# not-O	0.99 	0.91 	0.87 	0.89
#
# INFO:Entity level P/R/F1: 0.86/0.84/0.85
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 8 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 100s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	3004.00 	38.00   	25.00   	19.00   	63.00
# ORG     	153.00  	1630.00 	83.00   	100.00  	126.00
# LOC     	45.00   	77.00   	1913.00 	25.00   	34.00
# MISC    	38.00   	40.00   	41.00   	1047.00 	102.00
# O       	56.00   	43.00   	16.00   	51.00   	42593.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.91 	0.95 	0.93
# ORG  	0.99 	0.89 	0.78 	0.83
# LOC  	0.99 	0.92 	0.91 	0.92
# MISC 	0.99 	0.84 	0.83 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.90 	0.88 	0.89
#
# INFO:Entity level P/R/F1: 0.84/0.86/0.85
# INFO:New best score! Saving model in results/gru/20180220_101821/model.weights
#
# INFO:Epoch 9 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 95s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	3039.00 	13.00   	25.00   	18.00   	54.00
# ORG     	217.00  	1571.00 	92.00   	116.00  	96.00
# LOC     	83.00   	46.00   	1903.00 	39.00   	23.00
# MISC    	53.00   	24.00   	27.00   	1078.00 	86.00
# O       	71.00   	45.00   	18.00   	40.00   	42585.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.88 	0.97 	0.92
# ORG  	0.99 	0.92 	0.75 	0.83
# LOC  	0.99 	0.92 	0.91 	0.92
# MISC 	0.99 	0.84 	0.85 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.89 	0.88 	0.89
#
# INFO:Entity level P/R/F1: 0.84/0.86/0.85
#
# INFO:Epoch 10 out of 10
# INFO:Evaluating on development data
# 102/102 [==============================] - 97s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2951.00 	46.00   	53.00   	23.00   	76.00
# ORG     	132.00  	1672.00 	78.00   	98.00   	112.00
# LOC     	49.00   	93.00   	1892.00 	25.00   	35.00
# MISC    	29.00   	52.00   	42.00   	1049.00 	96.00
# O       	34.00   	55.00   	13.00   	34.00   	42623.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.92 	0.94 	0.93
# ORG  	0.99 	0.87 	0.80 	0.83
# LOC  	0.99 	0.91 	0.90 	0.91
# MISC 	0.99 	0.85 	0.83 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.89 	0.90
# not-O	0.99 	0.90 	0.88 	0.89
#
# INFO:Entity level P/R/F1: 0.84/0.86/0.85
#
# 102/102 [==============================] - 97s
